# %% [markdown]
# <a href="https://colab.research.google.com/github/sonalisanjeevprabu18/Neural-Network-and-Deep-Learning/blob/main/Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

from ultralytics import YOLO
import matplotlib.pyplot as plt
from PIL import Image

# Load pretrained YOLOv8 small model
model = YOLO("yolov8s.pt")

# Image path
image_path = "/content/bus.jpg"

# Run object detection
results = model(image_path)

# Show image with bounding boxes
results[0].show()

# Print detected objects with confidence
print("\nDetected Objects:")
for box in results[0].boxes:
    label = model.names[int(box.cls)]
    conf = float(box.conf)
    print(f"{label}: {conf:.2f}")
# Out:
# ...
#
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 523.2ms
# Speed: 5.2ms preprocess, 523.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
# <PIL.Image.Image image mode=RGB size=810x1080>
# Detected Objects:
# bus: 0.92
# person: 0.89
# person: 0.89
# person: 0.88
# person: 0.61
